# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelD22/ICD/blob/master/Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
energia = pd.read_csv('https://raw.githubusercontent.com/EisaacJC/Ciencia-de-Datos-Personal/master/energydata_complete.csv')

# %%
energia
# Out:
#                       date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0      2016-01-11 17:00:00          60      30  ...   5.300000  13.275433  13.275433
# 1      2016-01-11 17:10:00          60      30  ...   5.200000  18.606195  18.606195
# 2      2016-01-11 17:20:00          50      30  ...   5.100000  28.642668  28.642668
# 3      2016-01-11 17:30:00          50      40  ...   5.000000  45.410389  45.410389
# 4      2016-01-11 17:40:00          60      40  ...   4.900000  10.084097  10.084097
# ...                    ...         ...     ...  ...        ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  ...  13.333333  43.096812  43.096812
# 19731  2016-05-27 17:30:00          90       0  ...  13.300000  49.282940  49.282940
# 19732  2016-05-27 17:40:00         270      10  ...  13.266667  29.199117  29.199117
# 19733  2016-05-27 17:50:00         420      10  ...  13.233333   6.322784   6.322784
# ...

# %%
energy = energia.drop(['date', 'lights', 'rv1', 'rv2'],axis=1)

# %%
energy
# Out:
#        Appliances         T1       RH_1  ...  Windspeed  Visibility  Tdewpoint
# 0              60  19.890000  47.596667  ...   7.000000   63.000000   5.300000
# 1              60  19.890000  46.693333  ...   6.666667   59.166667   5.200000
# 2              50  19.890000  46.300000  ...   6.333333   55.333333   5.100000
# 3              50  19.890000  46.066667  ...   6.000000   51.500000   5.000000
# 4              60  19.890000  46.333333  ...   5.666667   47.666667   4.900000
# ...           ...        ...        ...  ...        ...         ...        ...
# 19730         100  25.566667  46.560000  ...   3.333333   23.666667  13.333333
# 19731          90  25.500000  46.500000  ...   3.500000   24.500000  13.300000
# 19732         270  25.500000  46.596667  ...   3.666667   25.333333  13.266667
# 19733         420  25.500000  46.990000  ...   3.833333   26.166667  13.233333
# 19734         430  25.500000  46.600000  ...   4.000000   27.000000  13.200000
#
# ...

# %%
n = energy.copy()

# %%
energ=n.drop(['Appliances'],axis=1)
Y=np.asarray(energy['Appliances'])

# %%
energ['unos']=1
energ
# Out:
#               T1       RH_1         T2  ...  Visibility  Tdewpoint  unos
# 0      19.890000  47.596667  19.200000  ...   63.000000   5.300000     1
# 1      19.890000  46.693333  19.200000  ...   59.166667   5.200000     1
# 2      19.890000  46.300000  19.200000  ...   55.333333   5.100000     1
# 3      19.890000  46.066667  19.200000  ...   51.500000   5.000000     1
# 4      19.890000  46.333333  19.200000  ...   47.666667   4.900000     1
# ...          ...        ...        ...  ...         ...        ...   ...
# 19730  25.566667  46.560000  25.890000  ...   23.666667  13.333333     1
# 19731  25.500000  46.500000  25.754000  ...   24.500000  13.300000     1
# 19732  25.500000  46.596667  25.628571  ...   25.333333  13.266667     1
# 19733  25.500000  46.990000  25.414000  ...   26.166667  13.233333     1
# 19734  25.500000  46.600000  25.264286  ...   27.000000  13.200000     1
#
# [19735 rows x 25 columns]

# %%
X=np.asarray(energ)

# %%
def calcula_costo(X,Y,theta):
  sumax = np.power(((X @ theta.T)-Y),2)
  return np.sum(sumax)/(2 * len(X))

# %%
def descenso(X,Y,theta,iters,alpha):
  costo = np.zeros(iters)
  for i in range(iters):
    theta=theta-(alpha/m)*(np.dot(X,theta)-Y).dot(X)
    costo[i] = calcula_costo(X, Y, theta)
  return theta,costo

# %%
thetai = np.arange(25)
alpha = 0.000001
iters = 10000
m = len(Y)

# %%
g,costo = descenso(X,Y,thetai,iters,alpha)
print(g)
costo_final = calcula_costo(X,Y,g)
# Out:
# [-2.74731973 -7.7822443  -1.18140982 -5.58326532  0.56665333 -1.64327101
#   3.33429415 -3.20692663  4.86555235  0.81861855  1.85320678  1.82450711
#   9.55046029  0.38790803 11.70623702  2.51462845 13.0030807   7.02097817
#  10.25221264 -1.62364838  3.07818964 19.3937515   5.55625412 12.84454188
#  23.96255559]

# %%
fig, ax = plt.subplots()  
ax.plot(np.arange(iters), costo)  
ax.set_xlabel('Iteraciones')  
ax.set_ylabel('Costo')
# Out:
# Text(0, 0.5, 'Costo')
